# %% [markdown]
# # Model Training for MUBA

# %%
import os, glob, re, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers, activations, optimizers, losses, metrics, initializers
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions

from keras import utils
from sklearn.preprocessing import LabelEncoder

# %%
# dir_path points towards where to find the image dataset
dir_path = "data/archive/Dataset_BUSI_with_GT/"
IMAGE_SHAPE = (224, 224)

random_sample = 1

# IMPORTANT - Check these are correct

MIXUP = True # Whether to train the model with mixup
ITERS = 3 # How many mixup images to create per image
BETA = True # Whether to sample from the beta function
BALANCE = True # Whether to balance the data and over-sample certain classes
AUG = True # whether to augment the data

# %%
# The data augmentation to do. This applies a random horizontal flip and a random tilt.
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal"),
  layers.RandomRotation((-0.05, 0.05)),
])

# create prepare_image method
# used to preprocess the image for efficientNet model

def prepare_image(file1: str, label1: str, file2: str = None, label2: str = None, beta = False, augment = True):
    """Prepares the image for the model

    Args:
        file1 (str): The path of  the first image
        label1 (str): The label of the first image
        file2 (str, optional): The path of  the second image. If not none, applies mixup. Defaults to None.
        label2 (str, optional): The label of the second image. Defaults to None.
        beta (bool, optional): If true, sample from teh beta function for mixup. Defaults to False.
        augment (bool, optional): If true, apply augmentations. Defaults to True.

    Returns:
        image, label
    """

    # Load the first image, apply augmentations
    img1 = image.load_img(file1, target_size=IMAGE_SHAPE)
    if augment:
        img1 = data_augmentation(img1)
    img_array = image.img_to_array(img1)
    label = label1

    if file2:

        # Load second image, apply augmentations
        img2 = image.load_img(file2, target_size=IMAGE_SHAPE)
        if augment:
            img2 = data_augmentation(img2)
        img_array2 = image.img_to_array(img2)

        # Generate alpha value for MixUp
        alpa = 0
        if beta:
            alpha = np.random.beta(0.2, 0.2, 1)
        else:
            alpha = random.random()

        # Combine the 2 images 
        img_array = (alpha * img_array) + ((1-alpha) * img_array2)
        label     = (alpha * label1) +    ((1-alpha) * label2)

    return tf.keras.applications.efficientnet.preprocess_input (img_array), label

# %%
# Read the folders folders
directories = os.listdir(dir_path)

files = [] 
labels = []

# Read files for each directory
for folder in directories:
    
    fileList = glob.glob(f'{dir_path}/{folder}/*')
    labels.extend([folder for _ in fileList])
    files.extend(fileList)

len(files), len(labels)
# Out:
# (1578, 1578)

# %%
# Count the number of labels to get an idea of how balanced the dataset is
unique, counts = np.unique(labels, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {'benign': 891, 'malignant': 421, 'normal': 266}

# %%
# One hot encoding

# Encode class values as integers
encoder = LabelEncoder()
encoder.fit(labels)
encoded_Y = encoder.transform(labels)

# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = utils.to_categorical(encoded_Y,dtype ="uint8", num_classes = 3)

labels = np.array(dummy_y)

print(f"Classes are {encoder.classes_}")
# Out:
# Classes are ['benign' 'malignant' 'normal']

# %%
# Create two lists to hold only non-mask images and label for each one
selected_files = []
selected_labels = []

for file, label in zip(files, labels):
    if 'mask' not in file:
        selected_files.append(file)
        selected_labels.append(label)

len(selected_files), len(selected_labels)
# Out:
# (780, 780)

# %%
#TEST MIXUP

test_image, label = prepare_image(selected_files[70], selected_labels[70],  selected_files[502], selected_labels[502], False)
test_image = tf.keras.utils.array_to_img(test_image)

print(f"Label is {label}")

plt.imshow(test_image, interpolation='nearest')
# Out:
# Label is [0.1555228 0.8444772 0.       ]

# %%
# Split the data into testing, training and validation data

x_train, x_tv, y_train, y_tv = train_test_split(selected_files, selected_labels, test_size=.3, random_state = random_sample)
x_test, x_val, y_test, y_val = train_test_split(x_tv, y_tv, test_size=.5, random_state = random_sample)

# %%
# The dictionary holds list of images and for each one has its target/label
images = {
    'image_train': [], 
    'target_train': [],
    'image_test': [], 
    'target_test': [],
    'image_val': [],
    'target_val': []
}

print('Preparing the images...')

def get_balance_iters(label):
    # Returns a value for over-sampling if balancing the data
    if label[0] == 1:
        return 1
    elif label[1] == 1:
        return 2
    else:
        return 3

print("Preparing training data")
for file, label in zip(x_train, y_train):
    # Only go through training data, testing data should not be used for mixup

    # If balancing the data, use the label to find out how many times to iterate through the image
    if BALANCE == True:
        balance_iters = get_balance_iters(label)
    else:
        balance_iters = 1

    for value in range(balance_iters):

        if MIXUP == False:
             # Prepare image without mixup
            new_file, new_label = prepare_image(file, label, beta = BETA, augment = AUG)
            images['image_train'].append(new_file)
            images['target_train'].append(new_label)

        elif MIXUP == True:
            # Prepare image with mixup
            # Iterate through the number of ITERS
            for i in range(ITERS):
                # Select a random file index
                random_file_i = random.randint(0,len(selected_files)-1)
                # Mixup the two images
                new_file, new_label = prepare_image(file, label, selected_files[random_file_i],selected_labels[random_file_i], beta = BETA, augment = AUG)
                images['image_train'].append(new_file)
                images['target_train'].append(new_label)

print("Preparing testing data")
for file, label in zip(x_test, y_test):

    # If balancing the data, use the label to find out how many times to iterate through the image
    if BALANCE == True:
        balance_iters = get_balance_iters(label)
    else:
        balance_iters = 1

    for value in range(balance_iters):
        # Prepare the image
        new_file, new_label = prepare_image(file, label, beta = BETA, augment = AUG)
        images['image_test'].append(new_file)
        images['target_test'].append(new_label)

print("Preparing validation data")
for file, label in zip(x_val, y_val):

    # If balancing the data, use the label to find out how many times to iterate through the image
    if BALANCE == True:
        balance_iters = get_balance_iters(label)
    else:
        balance_iters = 1

    for value in range(balance_iters):
        # Prepare the image
        new_file, new_label = prepare_image(file, label, beta = BETA, augment = AUG)
        images['image_val'].append(new_file)
        images['target_val'].append(new_label)

print('Finished.')
# Out:
# Preparing the images...
# Preparing training data
# Preparing testing data
# Preparing validation data
# Finished.

# %%
class_counts = [sum(col) for col in zip(*images['target_train'])]
print(f"Benign: {class_counts[0]}  Malignant: {class_counts[1]}  Normal: {class_counts[2]}")
# Out:
# Benign: 1211.3739518353793  Malignant: 803.2140513642922  Normal: 637.4119968003272

# %%
# convert lists to arrays 
x_train = np.array(images['image_train'])
y_train = np.array(images['target_train'])
x_test  = np.array(images['image_test'])
y_test  = np.array(images['target_test'])
x_val   = np.array(images['image_val'])
y_val   = np.array(images['target_val'])

# %%
x_train.shape, x_test.shape, x_val.shape, y_train.shape, y_test.shape, y_val.shape
# Out:
# ((2652, 224, 224, 3),
#  (188, 224, 224, 3),
#  (184, 224, 224, 3),
#  (2652, 3),
#  (188, 3),
#  (184, 3))

# %%
# The code is creating a ResNet152V2 model with pre-trained weights from the ImageNet dataset. 
# The base model is frozen, meaning its weights will not be updated during training. 
# The code then appends additional layers on top of the base model for transfer learning.

from tensorflow.keras.applications import resnet_v2
base_model = resnet_v2.ResNet152V2(
    include_top=False,
    weights='imagenet',
    input_shape=(*IMAGE_SHAPE, 3),
    classes=3)

# Freeze the base_model
base_model.trainable = False

# append my own layers on the top of the model for Transfer Learning
x = base_model.output

# 1st conv block
x = layers.Conv2D(256, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 2nd conv block
x = layers.Conv2D(128, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 1st FC layer
x = layers.Flatten()(x) 
x = layers.Dense(64)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# 2nd FC layer
x = layers.Dense(32, activation = 'relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(.2)(x)

x = layers.Dense(3, 'softmax')(x)

incept_model = keras.models.Model(inputs = base_model.input, outputs = x)

# compile the model
incept_model.compile(optimizer=optimizers.RMSprop(.001), loss = losses.categorical_crossentropy, metrics= [metrics.CategoricalAccuracy()])

# incept_model.summary()

# %%
EPOCHS = 60 #60
# Trains and returns incept_model. fit ( x_train y_train )
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='best_mixup_beta_model.h5', save_best_only=True) 

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=EPOCHS, validation_data=(x_val, y_val), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/60
# 83/83 [==============================] - ETA: 0s - loss: 1.0644 - categorical_accuracy: 0.5011
# c:\Users\Will Poulett\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 185s 2s/step - loss: 1.0644 - categorical_accuracy: 0.5011 - val_loss: 1.0868 - val_categorical_accuracy: 0.4891
# Epoch 2/60
# 83/83 [==============================] - 181s 2s/step - loss: 0.9663 - categorical_accuracy: 0.5592 - val_loss: 1.0935 - val_categorical_accuracy: 0.3696
# Epoch 3/60
# 83/83 [==============================] - 182s 2s/step - loss: 0.9219 - categorical_accuracy: 0.5694 - val_loss: 1.3810 - val_categorical_accuracy: 0.3424
# Epoch 4/60
# 83/83 [==============================] - 183s 2s/step - loss: 0.8939 - categorical_accuracy: 0.5965 - val_loss: 1.7873 - val_categorical_accuracy: 0.3424
# Epoch 5/60
# 83/83 [==============================] - 183s 2s/step - loss: 0.8525 - categorical_accuracy: 0.6195 - val_loss: 0.9818 - val_categorical_accuracy: 0.5272
# Epoch 6/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.8355 - categorical_accuracy: 0.6471 - val_loss: 1.3113 - val_categorical_accuracy: 0.3913
# Epoch 7/60
# 83/83 [==============================] - 187s 2s/step - loss: 0.8187 - categorical_accuracy: 0.6391 - val_loss: 1.3591 - val_categorical_accuracy: 0.5217
# Epoch 8/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.8098 - categorical_accuracy: 0.6482 - val_loss: 1.2693 - val_categorical_accuracy: 0.4674
# Epoch 9/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.8017 - categorical_accuracy: 0.6501 - val_loss: 1.8904 - val_categorical_accuracy: 0.4022
# Epoch 10/60
# 83/83 [==============================] - 193s 2s/step - loss: 0.7749 - categorical_accuracy: 0.6572 - val_loss: 1.2643 - val_categorical_accuracy: 0.5380
# Epoch 11/60
# 83/83 [==============================] - 187s 2s/step - loss: 0.7533 - categorical_accuracy: 0.6806 - val_loss: 3.2833 - val_categorical_accuracy: 0.3641
# Epoch 12/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.7474 - categorical_accuracy: 0.6814 - val_loss: 3.5930 - val_categorical_accuracy: 0.3750
# Epoch 13/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.7459 - categorical_accuracy: 0.6904 - val_loss: 2.1777 - val_categorical_accuracy: 0.3913
# Epoch 14/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.7180 - categorical_accuracy: 0.6980 - val_loss: 1.5124 - val_categorical_accuracy: 0.4457
# Epoch 15/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.7058 - categorical_accuracy: 0.7108 - val_loss: 1.3701 - val_categorical_accuracy: 0.5489
# Epoch 16/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.7135 - categorical_accuracy: 0.7149 - val_loss: 3.8051 - val_categorical_accuracy: 0.3641
# Epoch 17/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.6883 - categorical_accuracy: 0.7270 - val_loss: 2.5247 - val_categorical_accuracy: 0.3533
# Epoch 18/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.6795 - categorical_accuracy: 0.7229 - val_loss: 1.7162 - val_categorical_accuracy: 0.4891
# Epoch 19/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.6791 - categorical_accuracy: 0.7244 - val_loss: 1.2369 - val_categorical_accuracy: 0.5109
# Epoch 20/60
# 83/83 [==============================] - 204s 2s/step - loss: 0.6441 - categorical_accuracy: 0.7459 - val_loss: 1.2126 - val_categorical_accuracy: 0.5435
# Epoch 21/60
# 83/83 [==============================] - 200s 2s/step - loss: 0.6590 - categorical_accuracy: 0.7391 - val_loss: 3.7605 - val_categorical_accuracy: 0.3696
# Epoch 22/60
# 83/83 [==============================] - 208s 3s/step - loss: 0.6527 - categorical_accuracy: 0.7470 - val_loss: 1.3691 - val_categorical_accuracy: 0.5000
# Epoch 23/60
# 83/83 [==============================] - 209s 3s/step - loss: 0.6282 - categorical_accuracy: 0.7606 - val_loss: 2.2182 - val_categorical_accuracy: 0.4783
# Epoch 24/60
# 83/83 [==============================] - 204s 2s/step - loss: 0.6286 - categorical_accuracy: 0.7692 - val_loss: 3.9908 - val_categorical_accuracy: 0.3696
# Epoch 25/60
# 83/83 [==============================] - 209s 3s/step - loss: 0.5927 - categorical_accuracy: 0.7858 - val_loss: 5.9952 - val_categorical_accuracy: 0.3641
# Epoch 26/60
# 83/83 [==============================] - 207s 2s/step - loss: 0.5987 - categorical_accuracy: 0.7832 - val_loss: 1.5386 - val_categorical_accuracy: 0.4620
# Epoch 27/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.5854 - categorical_accuracy: 0.7930 - val_loss: 3.9244 - val_categorical_accuracy: 0.4185
# Epoch 28/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.5868 - categorical_accuracy: 0.7873 - val_loss: 1.5221 - val_categorical_accuracy: 0.5163
# Epoch 29/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.5752 - categorical_accuracy: 0.7979 - val_loss: 3.5029 - val_categorical_accuracy: 0.4946
# Epoch 30/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.5782 - categorical_accuracy: 0.7945 - val_loss: 1.4998 - val_categorical_accuracy: 0.4565
# Epoch 31/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.5718 - categorical_accuracy: 0.7945 - val_loss: 5.5803 - val_categorical_accuracy: 0.3859
# Epoch 32/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.5728 - categorical_accuracy: 0.8028 - val_loss: 3.5680 - val_categorical_accuracy: 0.4837
# Epoch 33/60
# 83/83 [==============================] - 733s 9s/step - loss: 0.5572 - categorical_accuracy: 0.8028 - val_loss: 1.1749 - val_categorical_accuracy: 0.5815
# Epoch 34/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.5514 - categorical_accuracy: 0.8081 - val_loss: 1.1728 - val_categorical_accuracy: 0.5978
# Epoch 35/60
# 83/83 [==============================] - 200s 2s/step - loss: 0.5512 - categorical_accuracy: 0.8171 - val_loss: 2.0867 - val_categorical_accuracy: 0.5000
# Epoch 36/60
# 83/83 [==============================] - 200s 2s/step - loss: 0.5320 - categorical_accuracy: 0.8156 - val_loss: 4.2484 - val_categorical_accuracy: 0.4783
# Epoch 37/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.5347 - categorical_accuracy: 0.8190 - val_loss: 1.2918 - val_categorical_accuracy: 0.5272
# Epoch 38/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.5255 - categorical_accuracy: 0.8265 - val_loss: 1.2809 - val_categorical_accuracy: 0.5217
# Epoch 39/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.5220 - categorical_accuracy: 0.8198 - val_loss: 1.4678 - val_categorical_accuracy: 0.5054
# Epoch 40/60
# 83/83 [==============================] - 190s 2s/step - loss: 0.5291 - categorical_accuracy: 0.8149 - val_loss: 4.6081 - val_categorical_accuracy: 0.4293
# Epoch 41/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.5142 - categorical_accuracy: 0.8269 - val_loss: 1.6923 - val_categorical_accuracy: 0.5380
# Epoch 42/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.5136 - categorical_accuracy: 0.8171 - val_loss: 6.4979 - val_categorical_accuracy: 0.3750
# Epoch 43/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.5072 - categorical_accuracy: 0.8356 - val_loss: 1.0190 - val_categorical_accuracy: 0.5870
# Epoch 44/60
# 83/83 [==============================] - 193s 2s/step - loss: 0.4828 - categorical_accuracy: 0.8473 - val_loss: 3.1508 - val_categorical_accuracy: 0.4783
# Epoch 45/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.4897 - categorical_accuracy: 0.8356 - val_loss: 3.2184 - val_categorical_accuracy: 0.4130
# Epoch 46/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.4909 - categorical_accuracy: 0.8431 - val_loss: 4.3669 - val_categorical_accuracy: 0.4022
# Epoch 47/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.4806 - categorical_accuracy: 0.8469 - val_loss: 0.8966 - val_categorical_accuracy: 0.6196
# Epoch 48/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.4786 - categorical_accuracy: 0.8416 - val_loss: 1.8489 - val_categorical_accuracy: 0.4728
# Epoch 49/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.4806 - categorical_accuracy: 0.8397 - val_loss: 9.8256 - val_categorical_accuracy: 0.3641
# Epoch 50/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.4814 - categorical_accuracy: 0.8469 - val_loss: 7.5251 - val_categorical_accuracy: 0.4076
# Epoch 51/60
# 83/83 [==============================] - 193s 2s/step - loss: 0.4763 - categorical_accuracy: 0.8495 - val_loss: 0.9733 - val_categorical_accuracy: 0.6304
# Epoch 52/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.4615 - categorical_accuracy: 0.8556 - val_loss: 1.2248 - val_categorical_accuracy: 0.6359
# Epoch 53/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.4615 - categorical_accuracy: 0.8567 - val_loss: 1.0847 - val_categorical_accuracy: 0.5707
# Epoch 54/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.4481 - categorical_accuracy: 0.8616 - val_loss: 3.1283 - val_categorical_accuracy: 0.5109
# Epoch 55/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.4382 - categorical_accuracy: 0.8752 - val_loss: 3.4224 - val_categorical_accuracy: 0.4022
# Epoch 56/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.4556 - categorical_accuracy: 0.8575 - val_loss: 3.7901 - val_categorical_accuracy: 0.5054
# Epoch 57/60
# 83/83 [==============================] - 189s 2s/step - loss: 0.4385 - categorical_accuracy: 0.8756 - val_loss: 2.1862 - val_categorical_accuracy: 0.5272
# Epoch 58/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.4423 - categorical_accuracy: 0.8737 - val_loss: 5.2784 - val_categorical_accuracy: 0.3913
# Epoch 59/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.4458 - categorical_accuracy: 0.8586 - val_loss: 3.7352 - val_categorical_accuracy: 0.4402
# Epoch 60/60
# 83/83 [==============================] - 189s 2s/step - loss: 0.4436 - categorical_accuracy: 0.8639 - val_loss: 2.1581 - val_categorical_accuracy: 0.5870

# %%
hist = history.history

plt.plot(hist['loss'], label=  'loss')
plt.plot(hist['val_loss'], label = 'val_loss')
plt.plot(hist['categorical_accuracy'], label='accuracy')
plt.plot(hist['val_categorical_accuracy'], label='val_accuracy')
plt.legend()

# %%
# Load the model with the best validation score
incept_model = keras.models.load_model('best_mixup_beta_model.h5')

incept_model.evaluate(x=x_test, y = y_test, batch_size=32, verbose=1)
# Out:
# 6/6 [==============================] - 13s 2s/step - loss: 0.7585 - categorical_accuracy: 0.7128
# [0.7584730982780457, 0.7127659320831299]

# %%
# open train the last 100 layers
for layer in incept_model.layers[720:]:
    layer.trainable = True
    
# compile the model with new optimizer and lr=.0001
incept_model.compile(optimizer=optimizers.RMSprop(.0001), loss = losses.categorical_crossentropy, metrics=[metrics.CategoricalAccuracy()])

# incept_model.summary()

# %%
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='best_mixup_beta_model_2.h5', save_best_only=True) 

# load the best weights
# incept_model.set_weights(best_weights)

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=EPOCHS, validation_data=(x_val, y_val), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.4209 - categorical_accuracy: 0.8816 - val_loss: 1.3654 - val_categorical_accuracy: 0.6141
# Epoch 2/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3924 - categorical_accuracy: 0.8944 - val_loss: 0.7932 - val_categorical_accuracy: 0.6793
# Epoch 3/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3914 - categorical_accuracy: 0.8937 - val_loss: 0.6416 - val_categorical_accuracy: 0.7228
# Epoch 4/60
# 83/83 [==============================] - 187s 2s/step - loss: 0.3923 - categorical_accuracy: 0.8944 - val_loss: 0.7700 - val_categorical_accuracy: 0.7446
# Epoch 5/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.3867 - categorical_accuracy: 0.8982 - val_loss: 0.9515 - val_categorical_accuracy: 0.6576
# Epoch 6/60
# 83/83 [==============================] - 187s 2s/step - loss: 0.3811 - categorical_accuracy: 0.8952 - val_loss: 0.7163 - val_categorical_accuracy: 0.7609
# Epoch 7/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.3852 - categorical_accuracy: 0.9001 - val_loss: 1.0147 - val_categorical_accuracy: 0.6196
# Epoch 8/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3755 - categorical_accuracy: 0.9069 - val_loss: 0.9846 - val_categorical_accuracy: 0.6467
# Epoch 9/60
# 83/83 [==============================] - 187s 2s/step - loss: 0.3707 - categorical_accuracy: 0.8989 - val_loss: 0.7342 - val_categorical_accuracy: 0.7228
# Epoch 10/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.3812 - categorical_accuracy: 0.9035 - val_loss: 0.7173 - val_categorical_accuracy: 0.7283
# Epoch 11/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.3838 - categorical_accuracy: 0.8929 - val_loss: 0.9608 - val_categorical_accuracy: 0.6359
# Epoch 12/60
# 83/83 [==============================] - 189s 2s/step - loss: 0.3828 - categorical_accuracy: 0.8982 - val_loss: 0.9290 - val_categorical_accuracy: 0.6848
# Epoch 13/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.3585 - categorical_accuracy: 0.9125 - val_loss: 0.7997 - val_categorical_accuracy: 0.7663
# Epoch 14/60
# 83/83 [==============================] - 193s 2s/step - loss: 0.3639 - categorical_accuracy: 0.9050 - val_loss: 0.6390 - val_categorical_accuracy: 0.7554
# Epoch 15/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3714 - categorical_accuracy: 0.9110 - val_loss: 1.4941 - val_categorical_accuracy: 0.5543
# Epoch 16/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3579 - categorical_accuracy: 0.9140 - val_loss: 0.7624 - val_categorical_accuracy: 0.6848
# Epoch 17/60
# 83/83 [==============================] - 188s 2s/step - loss: 0.3573 - categorical_accuracy: 0.9133 - val_loss: 0.6390 - val_categorical_accuracy: 0.7717
# Epoch 18/60
# 83/83 [==============================] - 191s 2s/step - loss: 0.3745 - categorical_accuracy: 0.9035 - val_loss: 0.7341 - val_categorical_accuracy: 0.7283
# Epoch 19/60
# 83/83 [==============================] - 192s 2s/step - loss: 0.3606 - categorical_accuracy: 0.9121 - val_loss: 0.7545 - val_categorical_accuracy: 0.7500
# Epoch 20/60
# 83/83 [==============================] - 197s 2s/step - loss: 0.3572 - categorical_accuracy: 0.9118 - val_loss: 0.6521 - val_categorical_accuracy: 0.7391
# Epoch 21/60
# 83/83 [==============================] - 236s 3s/step - loss: 0.3588 - categorical_accuracy: 0.9114 - val_loss: 0.9403 - val_categorical_accuracy: 0.7011
# Epoch 22/60
# 83/83 [==============================] - 204s 2s/step - loss: 0.3596 - categorical_accuracy: 0.9133 - val_loss: 0.9686 - val_categorical_accuracy: 0.6576
# Epoch 23/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.3544 - categorical_accuracy: 0.9087 - val_loss: 0.6912 - val_categorical_accuracy: 0.7609
# Epoch 24/60
# 83/83 [==============================] - 206s 2s/step - loss: 0.3490 - categorical_accuracy: 0.9140 - val_loss: 0.8904 - val_categorical_accuracy: 0.7391
# Epoch 25/60
# 83/83 [==============================] - 1863s 23s/step - loss: 0.3420 - categorical_accuracy: 0.9257 - val_loss: 0.7117 - val_categorical_accuracy: 0.7554
# Epoch 26/60
# 83/83 [==============================] - 182s 2s/step - loss: 0.3503 - categorical_accuracy: 0.9133 - val_loss: 0.7243 - val_categorical_accuracy: 0.7663
# Epoch 27/60
# 83/83 [==============================] - 186s 2s/step - loss: 0.3498 - categorical_accuracy: 0.9174 - val_loss: 1.0363 - val_categorical_accuracy: 0.7065
# Epoch 28/60
# 83/83 [==============================] - 189s 2s/step - loss: 0.3418 - categorical_accuracy: 0.9204 - val_loss: 1.0533 - val_categorical_accuracy: 0.7120
# Epoch 29/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.3468 - categorical_accuracy: 0.9137 - val_loss: 2.3710 - val_categorical_accuracy: 0.4620
# Epoch 30/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.3493 - categorical_accuracy: 0.9201 - val_loss: 1.8798 - val_categorical_accuracy: 0.5870
# Epoch 31/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.3388 - categorical_accuracy: 0.9242 - val_loss: 1.6929 - val_categorical_accuracy: 0.5598
# Epoch 32/60
# 83/83 [==============================] - 203s 2s/step - loss: 0.3475 - categorical_accuracy: 0.9170 - val_loss: 0.7325 - val_categorical_accuracy: 0.7609
# Epoch 33/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.3434 - categorical_accuracy: 0.9167 - val_loss: 0.9058 - val_categorical_accuracy: 0.6630
# Epoch 34/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.3398 - categorical_accuracy: 0.9204 - val_loss: 0.7913 - val_categorical_accuracy: 0.7554
# Epoch 35/60
# 83/83 [==============================] - 198s 2s/step - loss: 0.3380 - categorical_accuracy: 0.9261 - val_loss: 0.9397 - val_categorical_accuracy: 0.6902
# Epoch 36/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.3337 - categorical_accuracy: 0.9280 - val_loss: 1.0730 - val_categorical_accuracy: 0.6685
# Epoch 37/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.3458 - categorical_accuracy: 0.9110 - val_loss: 0.8796 - val_categorical_accuracy: 0.7283
# Epoch 38/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.3513 - categorical_accuracy: 0.9163 - val_loss: 1.0849 - val_categorical_accuracy: 0.6793
# Epoch 39/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.3286 - categorical_accuracy: 0.9310 - val_loss: 0.7730 - val_categorical_accuracy: 0.7283
# Epoch 40/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.3343 - categorical_accuracy: 0.9246 - val_loss: 0.7307 - val_categorical_accuracy: 0.7228
# Epoch 41/60
# 83/83 [==============================] - 197s 2s/step - loss: 0.3421 - categorical_accuracy: 0.9155 - val_loss: 1.1457 - val_categorical_accuracy: 0.6467
# Epoch 42/60
# 83/83 [==============================] - 200s 2s/step - loss: 0.3324 - categorical_accuracy: 0.9201 - val_loss: 0.7274 - val_categorical_accuracy: 0.7609
# Epoch 43/60
# 83/83 [==============================] - 200s 2s/step - loss: 0.3252 - categorical_accuracy: 0.9287 - val_loss: 1.1040 - val_categorical_accuracy: 0.6793
# Epoch 44/60
# 83/83 [==============================] - 209s 3s/step - loss: 0.3400 - categorical_accuracy: 0.9227 - val_loss: 1.6416 - val_categorical_accuracy: 0.5924
# Epoch 45/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.3401 - categorical_accuracy: 0.9212 - val_loss: 1.0463 - val_categorical_accuracy: 0.6793
# Epoch 46/60
# 83/83 [==============================] - 202s 2s/step - loss: 0.3273 - categorical_accuracy: 0.9291 - val_loss: 1.7379 - val_categorical_accuracy: 0.6467
# Epoch 47/60
# 83/83 [==============================] - 203s 2s/step - loss: 0.3316 - categorical_accuracy: 0.9235 - val_loss: 1.5827 - val_categorical_accuracy: 0.6196
# Epoch 48/60
# 83/83 [==============================] - 205s 2s/step - loss: 0.3271 - categorical_accuracy: 0.9321 - val_loss: 0.7570 - val_categorical_accuracy: 0.7609
# Epoch 49/60
# 83/83 [==============================] - 205s 2s/step - loss: 0.3251 - categorical_accuracy: 0.9250 - val_loss: 0.6885 - val_categorical_accuracy: 0.7609
# Epoch 50/60
# 83/83 [==============================] - 204s 2s/step - loss: 0.3273 - categorical_accuracy: 0.9231 - val_loss: 0.7630 - val_categorical_accuracy: 0.7446
# Epoch 51/60
# 83/83 [==============================] - 203s 2s/step - loss: 0.3163 - categorical_accuracy: 0.9370 - val_loss: 0.9712 - val_categorical_accuracy: 0.7609
# Epoch 52/60
# 83/83 [==============================] - 199s 2s/step - loss: 0.3361 - categorical_accuracy: 0.9250 - val_loss: 1.4753 - val_categorical_accuracy: 0.6359
# Epoch 53/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.3398 - categorical_accuracy: 0.9159 - val_loss: 1.5521 - val_categorical_accuracy: 0.5707
# Epoch 54/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.3252 - categorical_accuracy: 0.9261 - val_loss: 0.8311 - val_categorical_accuracy: 0.7663
# Epoch 55/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.3222 - categorical_accuracy: 0.9348 - val_loss: 0.5906 - val_categorical_accuracy: 0.7880
# Epoch 56/60
# 83/83 [==============================] - 201s 2s/step - loss: 0.3173 - categorical_accuracy: 0.9291 - val_loss: 1.6574 - val_categorical_accuracy: 0.6359
# Epoch 57/60
# 83/83 [==============================] - 196s 2s/step - loss: 0.3245 - categorical_accuracy: 0.9276 - val_loss: 1.0899 - val_categorical_accuracy: 0.7120
# Epoch 58/60
# 83/83 [==============================] - 194s 2s/step - loss: 0.3269 - categorical_accuracy: 0.9261 - val_loss: 1.0882 - val_categorical_accuracy: 0.7011
# Epoch 59/60
# 83/83 [==============================] - 203s 2s/step - loss: 0.3179 - categorical_accuracy: 0.9412 - val_loss: 1.4099 - val_categorical_accuracy: 0.6250
# Epoch 60/60
# 83/83 [==============================] - 195s 2s/step - loss: 0.3194 - categorical_accuracy: 0.9329 - val_loss: 0.6081 - val_categorical_accuracy: 0.7935

# %%
best_model = keras.models.load_model("best_mixup_beta_model_2.h5")

x = best_model.evaluate(x=x_test, y = y_test, batch_size=32, verbose=1)
# Out:
# 6/6 [==============================] - 14s 2s/step - loss: 0.5364 - categorical_accuracy: 0.7926
